# %%
import os
import sys
import pandas as pd

import numpy as np
from datetime import datetime as dt
import calendar
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '/Users/maoyabassiouni/Documents/DATA/Projects/OLNI'

# %%
def cal_vpd(air_temp, rh):
    def __esat(air_temp):
        return 610.8 * np.exp((17.27 * air_temp) / (air_temp + 237.3))
    return __esat(air_temp) * (1 - rh/100)

# %%
def f_temp(air_temp, pa):
    a =  np.exp((17.27 * air_temp) / (air_temp + 237.3))
    g = 0.665 * pa
    return a / (a + g)

# %%
models = ['ACCESS-CM2',
          'CanESM5',
          'CESM2',
          'CNRM-CM6-1',
          'EC-Earth3-Veg-LR',
          'FGOALS-g3',
          'GFDL-CM4',
          'GISS-E2-1-G',
          'IITM-ESM',
          'INM-CM5-0',
          'IPSL-CM6A-LR',
          'KIOST-ESM',
          'MIROC6',
          'MPI-ESM1-2-LR',
          'MRI-ESM2-0',
          'NorESM2-MM',
          'UKESM1-0-LL']

# %%
df_all = pd.read_csv(os.path.join(data_dir, 'model_inputs', 'df_model_all_LT_CMIP.csv'))
df_all['Lat'] = np.round(df_all['Lat'], 4)
df_all['Lon'] = np.round(df_all['Lon'], 4)

data_CMIP_co2 = pd.read_csv(os.path.join(data_dir, 'grid_data_extract', 'CMIP_historical_co2.csv'))
data_CMIP_co2 = data_CMIP_co2.drop(['Unnamed: 0',], axis=1)

data_CMIP = pd.read_csv(os.path.join(data_dir, 'grid_data_extract', 'CMIP_historical_models_annual.csv'))
#data_CMIP = pd.read_csv(os.path.join(data_dir, 'grid_data_extract', 'CMIP_historical_CESM2_annual.csv'))
data_CMIP['Lat'] = np.round(data_CMIP['Lat'], 4)
data_CMIP['Lon'] = np.round(data_CMIP['Lon'], 4)
data_CMIP = data_CMIP.groupby(['Lon', 'Lat', 'sp', 'year']).mean()
for k in data_CMIP.keys():
    if k.startswith('Unnamed'):
        data_CMIP = data_CMIP.drop([k,], axis=1)

        
data_CMIP = data_CMIP.reset_index()
df_all = df_all.reset_index()
df_all = pd.merge(df_all, data_CMIP, on=['Lat', 'Lon', 'sp'], how='outer')
df_all = df_all.drop(['index'], axis=1)

co2 = [data_CMIP_co2[data_CMIP_co2['year']==yi]['CO2_historical'].values[0] for yi in df_all['year']]
df_all['CO2_historical'] = co2

#conversions.... 
for source_id in models:
    for tt in ['gs_LTavg', 'gs']:
        df_all['par_historical_%s_%s' % (source_id, tt)] = df_all['rsds_historical_%s_%s' % (source_id, tt)] * 10 ** (-6) * 2.04
        df_all['vpd_historical_%s_%s' % (source_id, tt)] = cal_vpd(df_all['tas_historical_%s_%s' % (source_id, tt)], df_all['hurs_historical_%s_%s' % (source_id, tt)])

        df_all['rf_alpha_historical_%s_%s' % (source_id, tt)] = df_all['pr_historical_%s_%s' % (source_id, tt)]\
                                                     /  df_all['ERA5_rf_lambda_gs_LTavg']
        df_all['rf_lambda_historical_%s_%s' % (source_id, tt)] = df_all['ERA5_rf_lambda_gs_LTavg']
        df_all['pet_historical_%s_%s' % (source_id, tt)] = df_all['TC_pet_gs_LTavg'] \
                                                * df_all['rsds_historical_%s_%s' % (source_id, tt)] / df_all['TC_srad_gs_LTavg'] \
                                                * f_temp(df_all['tas_historical_%s_%s' % (source_id, tt)], df_all['elev_pa']) \
                                                / f_temp(df_all['TC_tmmn_gs_LTavg'], df_all['elev_pa'])

df_all.to_csv(os.path.join(data_dir, 'model_inputs', 'df_model_all_annual_CMIP_historical.csv'))

# %%
df_all
# Out:
#            Lat      Lon     sp          n  ymin  ymax  count  yrange  \
# 0      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 1      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 2      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 3      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 4      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# ...        ...      ...    ...        ...   ...   ...    ...     ...
# 67480  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 67481  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 67482  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 67483  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 67484  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
#
#        ERA5_rf_alpha_LTavg  ERA5_rf_lambda_LTavg  ...  \
# 0                 0.005236              0.603362  ...
# 1                 0.005236              0.603362  ...
# 2                 0.005236              0.603362  ...
# 3                 0.005236              0.603362  ...
# 4                 0.005236              0.603362  ...
# ...                    ...                   ...  ...
# 67480             0.002292              0.826733  ...
# 67481             0.002292              0.826733  ...
# 67482             0.002292              0.826733  ...
# 67483             0.002292              0.826733  ...
# 67484             0.002292              0.826733  ...
#
#        rf_lambda_historical_NorESM2-MM_gs  pet_historical_NorESM2-MM_gs  \
# 0                                0.431431                      0.004007
# 1                                0.431431                      0.004264
# 2                                0.431431                      0.004156
# 3                                0.431431                      0.004889
# 4                                0.431431                      0.004235
# ...                                   ...                           ...
# 67480                            1.008569                      0.003345
# 67481                            1.008569                      0.003214
# 67482                            1.008569                      0.003679
# 67483                            1.008569                      0.002865
# 67484                            1.008569                      0.002813
#
#        rf_alpha_historical_UKESM1-0-LL_gs_LTavg  \
# 0                                      0.004482
# 1                                      0.004482
# 2                                      0.004482
# 3                                      0.004482
# 4                                      0.004482
# ...                                         ...
# 67480                                  0.002841
# 67481                                  0.002841
# 67482                                  0.002841
# 67483                                  0.002841
# 67484                                  0.002841
#
#        rf_lambda_historical_UKESM1-0-LL_gs_LTavg  \
# 0                                       0.431431
# 1                                       0.431431
# 2                                       0.431431
# 3                                       0.431431
# 4                                       0.431431
# ...                                          ...
# 67480                                   1.008569
# 67481                                   1.008569
# 67482                                   1.008569
# 67483                                   1.008569
# 67484                                   1.008569
#
#        pet_historical_UKESM1-0-LL_gs_LTavg  par_historical_UKESM1-0-LL_gs  \
# 0                                 0.005323                       0.000521
# 1                                 0.005323                       0.000553
# 2                                 0.005323                       0.000526
# 3                                 0.005323                       0.000541
# 4                                 0.005323                       0.000562
# ...                                    ...                            ...
# 67480                             0.002946                       0.000318
# 67481                             0.002946                       0.000379
# 67482                             0.002946                       0.000359
# 67483                             0.002946                       0.000300
# 67484                             0.002946                       0.000390
#
#        vpd_historical_UKESM1-0-LL_gs  rf_alpha_historical_UKESM1-0-LL_gs  \
# 0                         529.089684                            0.005962
# 1                         531.732514                            0.006068
# 2                         356.698556                            0.006974
# 3                         448.877258                            0.007354
# 4                         700.915922                            0.003305
# ...                              ...                                 ...
# 67480                     319.233390                            0.002778
# 67481                     290.256302                            0.003378
# 67482                     306.894434                            0.003482
# 67483                     363.748036                            0.002545
# 67484                     287.616860                            0.003808
#
#        rf_lambda_historical_UKESM1-0-LL_gs  pet_historical_UKESM1-0-LL_gs
# 0                                 0.431431                       0.004873
# 1                                 0.431431                       0.005217
# 2                                 0.431431                       0.004460
# 3                                 0.431431                       0.004899
# 4                                 0.431431                       0.005593
# ...                                    ...                            ...
# 67480                             1.008569                       0.002552
# 67481                             1.008569                       0.003070
# 67482                             1.008569                       0.003008
# 67483                             1.008569                       0.002855
# 67484                             1.008569                       0.003244
#
# [67485 rows x 764 columns]

# %%
list(data_CMIP.keys())
# Out:
# ['Lon',
#  'Lat',
#  'sp',
#  'year',
#  'tas_historical_ACCESS-CM2',
#  'hurs_historical_ACCESS-CM2',
#  'pr_historical_ACCESS-CM2',
#  'rsds_historical_ACCESS-CM2',
#  'tas_historical_CanESM5',
#  'hurs_historical_CanESM5',
#  'pr_historical_CanESM5',
#  'rsds_historical_CanESM5',
#  'tas_historical_CESM2',
#  'hurs_historical_CESM2',
#  'pr_historical_CESM2',
#  'rsds_historical_CESM2',
#  'tas_historical_CNRM-CM6-1',
#  'hurs_historical_CNRM-CM6-1',
#  'pr_historical_CNRM-CM6-1',
#  'rsds_historical_CNRM-CM6-1',
#  'tas_historical_EC-Earth3-Veg-LR',
#  'hurs_historical_EC-Earth3-Veg-LR',
#  'pr_historical_EC-Earth3-Veg-LR',
#  'rsds_historical_EC-Earth3-Veg-LR',
#  'tas_historical_FGOALS-g3',
#  'hurs_historical_FGOALS-g3',
#  'pr_historical_FGOALS-g3',
#  'rsds_historical_FGOALS-g3',
#  'tas_historical_GFDL-CM4',
#  'hurs_historical_GFDL-CM4',
#  'pr_historical_GFDL-CM4',
#  'rsds_historical_GFDL-CM4',
#  'tas_historical_GISS-E2-1-G',
#  'hurs_historical_GISS-E2-1-G',
#  'pr_historical_GISS-E2-1-G',
#  'rsds_historical_GISS-E2-1-G',
#  'tas_historical_IITM-ESM',
#  'hurs_historical_IITM-ESM',
#  'pr_historical_IITM-ESM',
#  'rsds_historical_IITM-ESM',
#  'tas_historical_INM-CM5-0',
#  'hurs_historical_INM-CM5-0',
#  'pr_historical_INM-CM5-0',
#  'rsds_historical_INM-CM5-0',
#  'tas_historical_IPSL-CM6A-LR',
#  'hurs_historical_IPSL-CM6A-LR',
#  'pr_historical_IPSL-CM6A-LR',
#  'rsds_historical_IPSL-CM6A-LR',
#  'tas_historical_KIOST-ESM',
#  'hurs_historical_KIOST-ESM',
#  'pr_historical_KIOST-ESM',
#  'rsds_historical_KIOST-ESM',
#  'tas_historical_MIROC6',
#  'hurs_historical_MIROC6',
#  'pr_historical_MIROC6',
#  'rsds_historical_MIROC6',
#  'tas_historical_MPI-ESM1-2-LR',
#  'hurs_historical_MPI-ESM1-2-LR',
#  'pr_historical_MPI-ESM1-2-LR',
#  'rsds_historical_MPI-ESM1-2-LR',
#  'tas_historical_MRI-ESM2-0',
#  'hurs_historical_MRI-ESM2-0',
#  'pr_historical_MRI-ESM2-0',
#  'rsds_historical_MRI-ESM2-0',
#  'tas_historical_NorESM2-MM',
#  'hurs_historical_NorESM2-MM',
#  'pr_historical_NorESM2-MM',
#  'rsds_historical_NorESM2-MM',
#  'tas_historical_UKESM1-0-LL',
#  'hurs_historical_UKESM1-0-LL',
#  'pr_historical_UKESM1-0-LL',
#  'rsds_historical_UKESM1-0-LL',
#  'tas_historical_ACCESS-CM2_gs',
#  'hurs_historical_ACCESS-CM2_gs',
#  'pr_historical_ACCESS-CM2_gs',
#  'rsds_historical_ACCESS-CM2_gs',
#  'tas_historical_CanESM5_gs',
#  'hurs_historical_CanESM5_gs',
#  'pr_historical_CanESM5_gs',
#  'rsds_historical_CanESM5_gs',
#  'tas_historical_CESM2_gs',
#  'hurs_historical_CESM2_gs',
#  'pr_historical_CESM2_gs',
#  'rsds_historical_CESM2_gs',
#  'tas_historical_CNRM-CM6-1_gs',
#  'hurs_historical_CNRM-CM6-1_gs',
#  'pr_historical_CNRM-CM6-1_gs',
#  'rsds_historical_CNRM-CM6-1_gs',
#  'tas_historical_EC-Earth3-Veg-LR_gs',
#  'hurs_historical_EC-Earth3-Veg-LR_gs',
#  'pr_historical_EC-Earth3-Veg-LR_gs',
#  'rsds_historical_EC-Earth3-Veg-LR_gs',
#  'tas_historical_FGOALS-g3_gs',
#  'hurs_historical_FGOALS-g3_gs',
#  'pr_historical_FGOALS-g3_gs',
#  'rsds_historical_FGOALS-g3_gs',
#  'tas_historical_GFDL-CM4_gs',
#  'hurs_historical_GFDL-CM4_gs',
#  'pr_historical_GFDL-CM4_gs',
#  'rsds_historical_GFDL-CM4_gs',
#  'tas_historical_GISS-E2-1-G_gs',
#  'hurs_historical_GISS-E2-1-G_gs',
#  'pr_historical_GISS-E2-1-G_gs',
#  'rsds_historical_GISS-E2-1-G_gs',
#  'tas_historical_IITM-ESM_gs',
#  'hurs_historical_IITM-ESM_gs',
#  'pr_historical_IITM-ESM_gs',
#  'rsds_historical_IITM-ESM_gs',
#  'tas_historical_INM-CM5-0_gs',
#  'hurs_historical_INM-CM5-0_gs',
#  'pr_historical_INM-CM5-0_gs',
#  'rsds_historical_INM-CM5-0_gs',
#  'tas_historical_IPSL-CM6A-LR_gs',
#  'hurs_historical_IPSL-CM6A-LR_gs',
#  'pr_historical_IPSL-CM6A-LR_gs',
#  'rsds_historical_IPSL-CM6A-LR_gs',
#  'tas_historical_KIOST-ESM_gs',
#  'hurs_historical_KIOST-ESM_gs',
#  'pr_historical_KIOST-ESM_gs',
#  'rsds_historical_KIOST-ESM_gs',
#  'tas_historical_MIROC6_gs',
#  'hurs_historical_MIROC6_gs',
#  'pr_historical_MIROC6_gs',
#  'rsds_historical_MIROC6_gs',
#  'tas_historical_MPI-ESM1-2-LR_gs',
#  'hurs_historical_MPI-ESM1-2-LR_gs',
#  'pr_historical_MPI-ESM1-2-LR_gs',
#  'rsds_historical_MPI-ESM1-2-LR_gs',
#  'tas_historical_MRI-ESM2-0_gs',
#  'hurs_historical_MRI-ESM2-0_gs',
#  'pr_historical_MRI-ESM2-0_gs',
#  'rsds_historical_MRI-ESM2-0_gs',
#  'tas_historical_NorESM2-MM_gs',
#  'hurs_historical_NorESM2-MM_gs',
#  'pr_historical_NorESM2-MM_gs',
#  'rsds_historical_NorESM2-MM_gs',
#  'tas_historical_UKESM1-0-LL_gs',
#  'hurs_historical_UKESM1-0-LL_gs',
#  'pr_historical_UKESM1-0-LL_gs',
#  'rsds_historical_UKESM1-0-LL_gs',
#  'tas_historical_ACCESS-CM2_gs_peak',
#  'hurs_historical_ACCESS-CM2_gs_peak',
#  'pr_historical_ACCESS-CM2_gs_peak',
#  'rsds_historical_ACCESS-CM2_gs_peak',
#  'tas_historical_CanESM5_gs_peak',
#  'hurs_historical_CanESM5_gs_peak',
#  'pr_historical_CanESM5_gs_peak',
#  'rsds_historical_CanESM5_gs_peak',
#  'tas_historical_CESM2_gs_peak',
#  'hurs_historical_CESM2_gs_peak',
#  'pr_historical_CESM2_gs_peak',
#  'rsds_historical_CESM2_gs_peak',
#  'tas_historical_CNRM-CM6-1_gs_peak',
#  'hurs_historical_CNRM-CM6-1_gs_peak',
#  'pr_historical_CNRM-CM6-1_gs_peak',
#  'rsds_historical_CNRM-CM6-1_gs_peak',
#  'tas_historical_EC-Earth3-Veg-LR_gs_peak',
#  'hurs_historical_EC-Earth3-Veg-LR_gs_peak',
#  'pr_historical_EC-Earth3-Veg-LR_gs_peak',
#  'rsds_historical_EC-Earth3-Veg-LR_gs_peak',
#  'tas_historical_FGOALS-g3_gs_peak',
#  'hurs_historical_FGOALS-g3_gs_peak',
#  'pr_historical_FGOALS-g3_gs_peak',
#  'rsds_historical_FGOALS-g3_gs_peak',
#  'tas_historical_GFDL-CM4_gs_peak',
#  'hurs_historical_GFDL-CM4_gs_peak',
#  'pr_historical_GFDL-CM4_gs_peak',
#  'rsds_historical_GFDL-CM4_gs_peak',
#  'tas_historical_GISS-E2-1-G_gs_peak',
#  'hurs_historical_GISS-E2-1-G_gs_peak',
#  'pr_historical_GISS-E2-1-G_gs_peak',
#  'rsds_historical_GISS-E2-1-G_gs_peak',
#  'tas_historical_IITM-ESM_gs_peak',
#  'hurs_historical_IITM-ESM_gs_peak',
#  'pr_historical_IITM-ESM_gs_peak',
#  'rsds_historical_IITM-ESM_gs_peak',
#  'tas_historical_INM-CM5-0_gs_peak',
#  'hurs_historical_INM-CM5-0_gs_peak',
#  'pr_historical_INM-CM5-0_gs_peak',
#  'rsds_historical_INM-CM5-0_gs_peak',
#  'tas_historical_IPSL-CM6A-LR_gs_peak',
#  'hurs_historical_IPSL-CM6A-LR_gs_peak',
#  'pr_historical_IPSL-CM6A-LR_gs_peak',
#  'rsds_historical_IPSL-CM6A-LR_gs_peak',
#  'tas_historical_KIOST-ESM_gs_peak',
#  'hurs_historical_KIOST-ESM_gs_peak',
#  'pr_historical_KIOST-ESM_gs_peak',
#  'rsds_historical_KIOST-ESM_gs_peak',
#  'tas_historical_MIROC6_gs_peak',
#  'hurs_historical_MIROC6_gs_peak',
#  'pr_historical_MIROC6_gs_peak',
#  'rsds_historical_MIROC6_gs_peak',
#  'tas_historical_MPI-ESM1-2-LR_gs_peak',
#  'hurs_historical_MPI-ESM1-2-LR_gs_peak',
#  'pr_historical_MPI-ESM1-2-LR_gs_peak',
#  'rsds_historical_MPI-ESM1-2-LR_gs_peak',
#  'tas_historical_MRI-ESM2-0_gs_peak',
#  'hurs_historical_MRI-ESM2-0_gs_peak',
#  'pr_historical_MRI-ESM2-0_gs_peak',
#  'rsds_historical_MRI-ESM2-0_gs_peak',
#  'tas_historical_NorESM2-MM_gs_peak',
#  'hurs_historical_NorESM2-MM_gs_peak',
#  'pr_historical_NorESM2-MM_gs_peak',
#  'rsds_historical_NorESM2-MM_gs_peak',
#  'tas_historical_UKESM1-0-LL_gs_peak',
#  'hurs_historical_UKESM1-0-LL_gs_peak',
#  'pr_historical_UKESM1-0-LL_gs_peak',
#  'rsds_historical_UKESM1-0-LL_gs_peak']

# %%
df_all = pd.read_csv(os.path.join(data_dir, 'model_inputs', 'df_model_all_LT_CMIP.csv'))
df_all['Lat'] = np.round(df_all['Lat'], 4)
df_all['Lon'] = np.round(df_all['Lon'], 4)

data_CMIP_co2 = pd.read_csv(os.path.join(data_dir, 'grid_data_extract', 'CMIP_proj_co2.csv'))
data_CMIP_co2 = data_CMIP_co2.drop(['Unnamed: 0',], axis=1)

data_CMIP = pd.read_csv(os.path.join(data_dir, 'grid_data_extract', 'CMIP_proj_models_annual.csv'))
data_CMIP['Lat'] = np.round(data_CMIP['Lat'], 4)
data_CMIP['Lon'] = np.round(data_CMIP['Lon'], 4)
data_CMIP = data_CMIP.groupby(['Lon', 'Lat', 'sp', 'year']).mean()
for k in data_CMIP.keys():
    if k.startswith('Unnamed'):
        data_CMIP = data_CMIP.drop([k,], axis=1)

        
data_CMIP = data_CMIP.reset_index()
df_all = df_all.reset_index()
df_all = pd.merge(df_all, data_CMIP, on=['Lat', 'Lon', 'sp'], how='outer')
df_all = df_all.drop(['index'], axis=1)

for ck in ['CO2_ssp245', 'CO2_ssp585']:
    co2 = [data_CMIP_co2[data_CMIP_co2['year']==yi][ck].values[0] for yi in df_all['year']]
    df_all[ck] = co2

#conversions.... 
for source_id in models:
    for sc in ['ssp245', 'ssp585']:
        for tt in [ 'gs',]:
            df_all['par_%s_%s_%s' % (sc, source_id, tt)] = df_all['rsds_%s_%s_%s' % (sc, source_id, tt)] * 10 ** (-6) * 2.04
            df_all['vpd_%s_%s_%s' % (sc, source_id, tt)] = cal_vpd(df_all['tas_%s_%s_%s' % (sc, source_id, tt)], df_all['hurs_%s_%s_%s' % (sc, source_id, tt)])

            df_all['rf_alpha_%s_%s_%s' % (sc, source_id, tt)] = df_all['pr_%s_%s_%s' % (sc, source_id, tt)]\
                                                         /  df_all['ERA5_rf_lambda_gs_LTavg']
            df_all['rf_lambda_%s_%s_%s' % (sc, source_id, tt)] = df_all['ERA5_rf_lambda_gs_LTavg']
            df_all['pet_%s_%s_%s' % (sc, source_id, tt)] = df_all['TC_pet_gs_LTavg'] \
                                                    * df_all['rsds_%s_%s_%s' % (sc, source_id, tt)] / df_all['TC_srad_gs_LTavg'] \
                                                    * f_temp(df_all['tas_%s_%s_%s' % (sc, source_id, tt)], df_all['elev_pa']) \
                                                / f_temp(df_all['TC_tmmn_gs_LTavg'], df_all['elev_pa'])

df_all.to_csv(os.path.join(data_dir, 'model_inputs', 'df_model_all_annual_CMIP_proj.csv'))

# %%
df_all
# Out:
#            Lat      Lon     sp          n  ymin  ymax  count  yrange  \
# 0      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 1      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 2      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 3      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# 4      43.2562  -8.8250  129.0  10.700972  1995  2015     12      20
# ...        ...      ...    ...        ...   ...   ...    ...     ...
# 35169  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 35170  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 35171  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 35172  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
# 35173  66.3025  29.5011  118.0   9.483958  1995  2009      8      14
#
#        ERA5_rf_alpha_LTavg  ERA5_rf_lambda_LTavg  ...  \
# 0                 0.005236              0.603362  ...
# 1                 0.005236              0.603362  ...
# 2                 0.005236              0.603362  ...
# 3                 0.005236              0.603362  ...
# 4                 0.005236              0.603362  ...
# ...                    ...                   ...  ...
# 35169             0.002292              0.826733  ...
# 35170             0.002292              0.826733  ...
# 35171             0.002292              0.826733  ...
# 35172             0.002292              0.826733  ...
# 35173             0.002292              0.826733  ...
#
#        par_ssp245_UKESM1-0-LL_gs  vpd_ssp245_UKESM1-0-LL_gs  \
# 0                       0.000525                 736.918075
# 1                       0.000507                 704.159871
# 2                       0.000523                 672.290184
# 3                       0.000517                 660.204245
# 4                       0.000547                 704.824699
# ...                          ...                        ...
# 35169                        NaN                 480.317320
# 35170                        NaN                 510.867626
# 35171                        NaN                 562.682593
# 35172                        NaN                 491.848681
# 35173                        NaN                 608.567615
#
#        rf_alpha_ssp245_UKESM1-0-LL_gs  rf_lambda_ssp245_UKESM1-0-LL_gs  \
# 0                            0.004833                         0.431431
# 1                            0.005030                         0.431431
# 2                            0.004124                         0.431431
# 3                            0.005080                         0.431431
# 4                            0.003112                         0.431431
# ...                               ...                              ...
# 35169                        0.002130                         1.008569
# 35170                        0.005737                         1.008569
# 35171                        0.003362                         1.008569
# 35172                        0.002669                         1.008569
# 35173                        0.003368                         1.008569
#
#        pet_ssp245_UKESM1-0-LL_gs  par_ssp585_UKESM1-0-LL_gs  \
# 0                       0.005607                   0.000546
# 1                       0.005334                   0.000546
# 2                       0.005349                   0.000546
# 3                       0.005650                   0.000551
# 4                       0.005569                   0.000558
# ...                          ...                        ...
# 35169                        NaN                   0.000478
# 35170                        NaN                   0.000403
# 35171                        NaN                   0.000418
# 35172                        NaN                   0.000468
# 35173                        NaN                   0.000423
#
#        vpd_ssp585_UKESM1-0-LL_gs  rf_alpha_ssp585_UKESM1-0-LL_gs  \
# 0                    1256.758573                        0.000374
# 1                    1142.456603                        0.000468
# 2                    1224.531955                        0.000512
# 3                    1165.962660                        0.001235
# 4                    1495.877251                        0.000190
# ...                          ...                             ...
# 35169                1032.447782                        0.002323
# 35170                 906.044317                        0.003708
# 35171                1079.335588                        0.003673
# 35172                1294.224635                        0.002144
# 35173                 928.096542                        0.003562
#
#        rf_lambda_ssp585_UKESM1-0-LL_gs  pet_ssp585_UKESM1-0-LL_gs
# 0                             0.431431                   0.010409
# 1                             0.431431                   0.010391
# 2                             0.431431                   0.010706
# 3                             0.431431                   0.010559
# 4                             0.431431                   0.011462
# ...                                ...                        ...
# 35169                         1.008569                   0.008812
# 35170                         1.008569                   0.007559
# 35171                         1.008569                   0.008503
# 35172                         1.008569                   0.010362
# 35173                         1.008569                   0.007880
#
# [35174 rows x 1003 columns]

# %%
list(df_all.keys())
# Out:
# ['Lat',
#  'Lon',
#  'sp',
#  'n',
#  'ymin',
#  'ymax',
#  'count',
#  'yrange',
#  'ERA5_rf_alpha_LTavg',
#  'ERA5_rf_lambda_LTavg',
#  'ERA5_rf_alpha_gs_LTavg',
#  'ERA5_rf_lambda_gs_LTavg',
#  'ERA5_tmp_LTavg',
#  'ERA5_tmp_gs_LTavg',
#  'ERA5_tmp_gs_peak_LTavg',
#  'ERA5_pre_LTavg',
#  'ERA5_pre_gs_LTavg',
#  'ERA5_pre_gs_peak_LTavg',
#  'ERA5_pa_LTavg',
#  'ERA5_pa_gs_LTavg',
#  'ERA5_pa_gs_peak_LTavg',
#  'ERA5_rf_alpha_LTstd',
#  'ERA5_rf_lambda_LTstd',
#  'ERA5_rf_alpha_gs_LTstd',
#  'ERA5_rf_lambda_gs_LTstd',
#  'ERA5_tmp_LTstd',
#  'ERA5_tmp_gs_LTstd',
#  'ERA5_tmp_gs_peak_LTstd',
#  'ERA5_pre_LTstd',
#  'ERA5_pre_gs_LTstd',
#  'ERA5_pre_gs_peak_LTstd',
#  'ERA5_pa_LTstd',
#  'ERA5_pa_gs_LTstd',
#  'ERA5_pa_gs_peak_LTstd',
#  'TC_srad_LTavg',
#  'TC_pet_LTavg',
#  'TC_aet_LTavg',
#  'TC_def_LTavg',
#  'TC_pdsi_LTavg',
#  'TC_ro_LTavg',
#  'TC_soil_LTavg',
#  'TC_tmmn_LTavg',
#  'TC_tmmx_LTavg',
#  'TC_vap_LTavg',
#  'TC_vpd_LTavg',
#  'TC_vs_LTavg',
#  'TC_days_month_LTavg',
#  'TC_tmean_LTavg',
#  'TC_aet_gs_LTavg',
#  'TC_def_gs_LTavg',
#  'TC_pdsi_gs_LTavg',
#  'TC_pet_gs_LTavg',
#  'TC_ro_gs_LTavg',
#  'TC_soil_gs_LTavg',
#  'TC_srad_gs_LTavg',
#  'TC_tmean_gs_LTavg',
#  'TC_tmmn_gs_LTavg',
#  'TC_tmmx_gs_LTavg',
#  'TC_vap_gs_LTavg',
#  'TC_vpd_gs_LTavg',
#  'TC_vs_gs_LTavg',
#  'TC_aet_gs_peak_LTavg',
#  'TC_def_gs_peak_LTavg',
#  'TC_pdsi_gs_peak_LTavg',
#  'TC_pet_gs_peak_LTavg',
#  'TC_ro_gs_peak_LTavg',
#  'TC_soil_gs_peak_LTavg',
#  'TC_srad_gs_peak_LTavg',
#  'TC_tmean_gs_peak_LTavg',
#  'TC_tmmn_gs_peak_LTavg',
#  'TC_tmmx_gs_peak_LTavg',
#  'TC_vap_gs_peak_LTavg',
#  'TC_vpd_gs_peak_LTavg',
#  'TC_vs_gs_peak_LTavg',
#  'TC_pre_LTavg',
#  'TC_pre_gs_LTavg',
#  'TC_pre_gs_peak_LTavg',
#  'TC_tmp_LTavg',
#  'TC_tmp_gs_LTavg',
#  'TC_tmp_gs_peak_LTavg',
#  'TC_par_LTavg',
#  'TC_par_gs_LTavg',
#  'TC_par_gs_peak_LTavg',
#  'TC_srad_LTstd',
#  'TC_pet_LTstd',
#  'TC_aet_LTstd',
#  'TC_def_LTstd',
#  'TC_pdsi_LTstd',
#  'TC_ro_LTstd',
#  'TC_soil_LTstd',
#  'TC_tmmn_LTstd',
#  'TC_tmmx_LTstd',
#  'TC_vap_LTstd',
#  'TC_vpd_LTstd',
#  'TC_vs_LTstd',
#  'TC_days_month_LTstd',
#  'TC_tmean_LTstd',
#  'TC_aet_gs_LTstd',
#  'TC_def_gs_LTstd',
#  'TC_pdsi_gs_LTstd',
#  'TC_pet_gs_LTstd',
#  'TC_ro_gs_LTstd',
#  'TC_soil_gs_LTstd',
#  'TC_srad_gs_LTstd',
#  'TC_tmean_gs_LTstd',
#  'TC_tmmn_gs_LTstd',
#  'TC_tmmx_gs_LTstd',
#  'TC_vap_gs_LTstd',
#  'TC_vpd_gs_LTstd',
#  'TC_vs_gs_LTstd',
#  'TC_aet_gs_peak_LTstd',
#  'TC_def_gs_peak_LTstd',
#  'TC_pdsi_gs_peak_LTstd',
#  'TC_pet_gs_peak_LTstd',
#  'TC_ro_gs_peak_LTstd',
#  'TC_soil_gs_peak_LTstd',
#  'TC_srad_gs_peak_LTstd',
#  'TC_tmean_gs_peak_LTstd',
#  'TC_tmmn_gs_peak_LTstd',
#  'TC_tmmx_gs_peak_LTstd',
#  'TC_vap_gs_peak_LTstd',
#  'TC_vpd_gs_peak_LTstd',
#  'TC_vs_gs_peak_LTstd',
#  'TC_pre_LTstd',
#  'TC_pre_gs_LTstd',
#  'TC_pre_gs_peak_LTstd',
#  'TC_tmp_LTstd',
#  'TC_tmp_gs_LTstd',
#  'TC_tmp_gs_peak_LTstd',
#  'TC_par_LTstd',
#  'TC_par_gs_LTstd',
#  'TC_par_gs_peak_LTstd',
#  'MODIS_f_nontree',
#  'MODIS_f_tree',
#  'MODIS_f_nonveg',
#  'MODIS_tot',
#  'MODIS_f_veg',
#  'MODIS_Lai',
#  'MODIS_Fpar',
#  'MODIS_Fpar_gs',
#  'MODIS_Lai_gs',
#  'MODIS_Fpar_gs_peak',
#  'MODIS_Lai_gs_peak',
#  'b0',
#  'b10',
#  'b30',
#  'b60',
#  'b100',
#  'b200',
#  'ID_ruc',
#  'BB',
#  'DRYSMC',
#  'MAXSMC',
#  'REFSMC',
#  'SATPSI',
#  'SATDK',
#  'WLTSMC',
#  'leaf',
#  'kxlmax',
#  'Px50',
#  'Pg50',
#  'Zr',
#  'RAI',
#  'piR',
#  'hc',
#  'sp_id',
#  'months_gs',
#  'gs_lai',
#  'peak_gs_month',
#  'peak_lai',
#  'Td',
#  'T_GS',
#  'porosity',
#  'Ks',
#  's_h',
#  's_fc',
#  'fparl',
#  'elevation',
#  'forest_height',
#  'elev_pa',
#  'CO2_historical_LTavg',
#  'CO2_LTavg',
#  'CO2_ssp245_LTavg',
#  'CO2_ssp585_LTavg',
#  'tas_historical_ACCESS-CM2_LTavg',
#  'hurs_historical_ACCESS-CM2_LTavg',
#  'pr_historical_ACCESS-CM2_LTavg',
#  'rsds_historical_ACCESS-CM2_LTavg',
#  'tas_historical_CanESM5_LTavg',
#  'hurs_historical_CanESM5_LTavg',
#  'pr_historical_CanESM5_LTavg',
#  'rsds_historical_CanESM5_LTavg',
#  'tas_historical_CESM2_LTavg',
#  'hurs_historical_CESM2_LTavg',
#  'pr_historical_CESM2_LTavg',
#  'rsds_historical_CESM2_LTavg',
#  'tas_historical_CNRM-CM6-1_LTavg',
#  'hurs_historical_CNRM-CM6-1_LTavg',
#  'pr_historical_CNRM-CM6-1_LTavg',
#  'rsds_historical_CNRM-CM6-1_LTavg',
#  'tas_historical_EC-Earth3-Veg-LR_LTavg',
#  'hurs_historical_EC-Earth3-Veg-LR_LTavg',
#  'pr_historical_EC-Earth3-Veg-LR_LTavg',
#  'rsds_historical_EC-Earth3-Veg-LR_LTavg',
#  'tas_historical_FGOALS-g3_LTavg',
#  'hurs_historical_FGOALS-g3_LTavg',
#  'pr_historical_FGOALS-g3_LTavg',
#  'rsds_historical_FGOALS-g3_LTavg',
#  'tas_historical_GFDL-CM4_LTavg',
#  'hurs_historical_GFDL-CM4_LTavg',
#  'pr_historical_GFDL-CM4_LTavg',
#  'rsds_historical_GFDL-CM4_LTavg',
#  'tas_historical_GISS-E2-1-G_LTavg',
#  'hurs_historical_GISS-E2-1-G_LTavg',
#  'pr_historical_GISS-E2-1-G_LTavg',
#  'rsds_historical_GISS-E2-1-G_LTavg',
#  'tas_historical_IITM-ESM_LTavg',
#  'hurs_historical_IITM-ESM_LTavg',
#  'pr_historical_IITM-ESM_LTavg',
#  'rsds_historical_IITM-ESM_LTavg',
#  'tas_historical_INM-CM5-0_LTavg',
#  'hurs_historical_INM-CM5-0_LTavg',
#  'pr_historical_INM-CM5-0_LTavg',
#  'rsds_historical_INM-CM5-0_LTavg',
#  'tas_historical_IPSL-CM6A-LR_LTavg',
#  'hurs_historical_IPSL-CM6A-LR_LTavg',
#  'pr_historical_IPSL-CM6A-LR_LTavg',
#  'rsds_historical_IPSL-CM6A-LR_LTavg',
#  'tas_historical_KIOST-ESM_LTavg',
#  'hurs_historical_KIOST-ESM_LTavg',
#  'pr_historical_KIOST-ESM_LTavg',
#  'rsds_historical_KIOST-ESM_LTavg',
#  'tas_historical_MIROC6_LTavg',
#  'hurs_historical_MIROC6_LTavg',
#  'pr_historical_MIROC6_LTavg',
#  'rsds_historical_MIROC6_LTavg',
#  'tas_historical_MPI-ESM1-2-LR_LTavg',
#  'hurs_historical_MPI-ESM1-2-LR_LTavg',
#  'pr_historical_MPI-ESM1-2-LR_LTavg',
#  'rsds_historical_MPI-ESM1-2-LR_LTavg',
#  'tas_historical_MRI-ESM2-0_LTavg',
#  'hurs_historical_MRI-ESM2-0_LTavg',
#  'pr_historical_MRI-ESM2-0_LTavg',
#  'rsds_historical_MRI-ESM2-0_LTavg',
#  'tas_historical_NorESM2-MM_LTavg',
#  'hurs_historical_NorESM2-MM_LTavg',
#  'pr_historical_NorESM2-MM_LTavg',
#  'rsds_historical_NorESM2-MM_LTavg',
#  'tas_historical_UKESM1-0-LL_LTavg',
#  'hurs_historical_UKESM1-0-LL_LTavg',
#  'pr_historical_UKESM1-0-LL_LTavg',
#  'rsds_historical_UKESM1-0-LL_LTavg',
#  'tas_historical_ACCESS-CM2_gs_LTavg',
#  'hurs_historical_ACCESS-CM2_gs_LTavg',
#  'pr_historical_ACCESS-CM2_gs_LTavg',
#  'rsds_historical_ACCESS-CM2_gs_LTavg',
#  'tas_historical_CanESM5_gs_LTavg',
#  'hurs_historical_CanESM5_gs_LTavg',
#  'pr_historical_CanESM5_gs_LTavg',
#  'rsds_historical_CanESM5_gs_LTavg',
#  'tas_historical_CESM2_gs_LTavg',
#  'hurs_historical_CESM2_gs_LTavg',
#  'pr_historical_CESM2_gs_LTavg',
#  'rsds_historical_CESM2_gs_LTavg',
#  'tas_historical_CNRM-CM6-1_gs_LTavg',
#  'hurs_historical_CNRM-CM6-1_gs_LTavg',
#  'pr_historical_CNRM-CM6-1_gs_LTavg',
#  'rsds_historical_CNRM-CM6-1_gs_LTavg',
#  'tas_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'hurs_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'pr_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'rsds_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'tas_historical_FGOALS-g3_gs_LTavg',
#  'hurs_historical_FGOALS-g3_gs_LTavg',
#  'pr_historical_FGOALS-g3_gs_LTavg',
#  'rsds_historical_FGOALS-g3_gs_LTavg',
#  'tas_historical_GFDL-CM4_gs_LTavg',
#  'hurs_historical_GFDL-CM4_gs_LTavg',
#  'pr_historical_GFDL-CM4_gs_LTavg',
#  'rsds_historical_GFDL-CM4_gs_LTavg',
#  'tas_historical_GISS-E2-1-G_gs_LTavg',
#  'hurs_historical_GISS-E2-1-G_gs_LTavg',
#  'pr_historical_GISS-E2-1-G_gs_LTavg',
#  'rsds_historical_GISS-E2-1-G_gs_LTavg',
#  'tas_historical_IITM-ESM_gs_LTavg',
#  'hurs_historical_IITM-ESM_gs_LTavg',
#  'pr_historical_IITM-ESM_gs_LTavg',
#  'rsds_historical_IITM-ESM_gs_LTavg',
#  'tas_historical_INM-CM5-0_gs_LTavg',
#  'hurs_historical_INM-CM5-0_gs_LTavg',
#  'pr_historical_INM-CM5-0_gs_LTavg',
#  'rsds_historical_INM-CM5-0_gs_LTavg',
#  'tas_historical_IPSL-CM6A-LR_gs_LTavg',
#  'hurs_historical_IPSL-CM6A-LR_gs_LTavg',
#  'pr_historical_IPSL-CM6A-LR_gs_LTavg',
#  'rsds_historical_IPSL-CM6A-LR_gs_LTavg',
#  'tas_historical_KIOST-ESM_gs_LTavg',
#  'hurs_historical_KIOST-ESM_gs_LTavg',
#  'pr_historical_KIOST-ESM_gs_LTavg',
#  'rsds_historical_KIOST-ESM_gs_LTavg',
#  'tas_historical_MIROC6_gs_LTavg',
#  'hurs_historical_MIROC6_gs_LTavg',
#  'pr_historical_MIROC6_gs_LTavg',
#  'rsds_historical_MIROC6_gs_LTavg',
#  'tas_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'hurs_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'pr_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'rsds_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'tas_historical_MRI-ESM2-0_gs_LTavg',
#  'hurs_historical_MRI-ESM2-0_gs_LTavg',
#  'pr_historical_MRI-ESM2-0_gs_LTavg',
#  'rsds_historical_MRI-ESM2-0_gs_LTavg',
#  'tas_historical_NorESM2-MM_gs_LTavg',
#  'hurs_historical_NorESM2-MM_gs_LTavg',
#  'pr_historical_NorESM2-MM_gs_LTavg',
#  'rsds_historical_NorESM2-MM_gs_LTavg',
#  'tas_historical_UKESM1-0-LL_gs_LTavg',
#  'hurs_historical_UKESM1-0-LL_gs_LTavg',
#  'pr_historical_UKESM1-0-LL_gs_LTavg',
#  'rsds_historical_UKESM1-0-LL_gs_LTavg',
#  'tas_historical_ACCESS-CM2_gs_peak_LTavg',
#  'hurs_historical_ACCESS-CM2_gs_peak_LTavg',
#  'pr_historical_ACCESS-CM2_gs_peak_LTavg',
#  'rsds_historical_ACCESS-CM2_gs_peak_LTavg',
#  'tas_historical_CanESM5_gs_peak_LTavg',
#  'hurs_historical_CanESM5_gs_peak_LTavg',
#  'pr_historical_CanESM5_gs_peak_LTavg',
#  'rsds_historical_CanESM5_gs_peak_LTavg',
#  'tas_historical_CESM2_gs_peak_LTavg',
#  'hurs_historical_CESM2_gs_peak_LTavg',
#  'pr_historical_CESM2_gs_peak_LTavg',
#  'rsds_historical_CESM2_gs_peak_LTavg',
#  'tas_historical_CNRM-CM6-1_gs_peak_LTavg',
#  'hurs_historical_CNRM-CM6-1_gs_peak_LTavg',
#  'pr_historical_CNRM-CM6-1_gs_peak_LTavg',
#  'rsds_historical_CNRM-CM6-1_gs_peak_LTavg',
#  'tas_historical_EC-Earth3-Veg-LR_gs_peak_LTavg',
#  'hurs_historical_EC-Earth3-Veg-LR_gs_peak_LTavg',
#  'pr_historical_EC-Earth3-Veg-LR_gs_peak_LTavg',
#  'rsds_historical_EC-Earth3-Veg-LR_gs_peak_LTavg',
#  'tas_historical_FGOALS-g3_gs_peak_LTavg',
#  'hurs_historical_FGOALS-g3_gs_peak_LTavg',
#  'pr_historical_FGOALS-g3_gs_peak_LTavg',
#  'rsds_historical_FGOALS-g3_gs_peak_LTavg',
#  'tas_historical_GFDL-CM4_gs_peak_LTavg',
#  'hurs_historical_GFDL-CM4_gs_peak_LTavg',
#  'pr_historical_GFDL-CM4_gs_peak_LTavg',
#  'rsds_historical_GFDL-CM4_gs_peak_LTavg',
#  'tas_historical_GISS-E2-1-G_gs_peak_LTavg',
#  'hurs_historical_GISS-E2-1-G_gs_peak_LTavg',
#  'pr_historical_GISS-E2-1-G_gs_peak_LTavg',
#  'rsds_historical_GISS-E2-1-G_gs_peak_LTavg',
#  'tas_historical_IITM-ESM_gs_peak_LTavg',
#  'hurs_historical_IITM-ESM_gs_peak_LTavg',
#  'pr_historical_IITM-ESM_gs_peak_LTavg',
#  'rsds_historical_IITM-ESM_gs_peak_LTavg',
#  'tas_historical_INM-CM5-0_gs_peak_LTavg',
#  'hurs_historical_INM-CM5-0_gs_peak_LTavg',
#  'pr_historical_INM-CM5-0_gs_peak_LTavg',
#  'rsds_historical_INM-CM5-0_gs_peak_LTavg',
#  'tas_historical_IPSL-CM6A-LR_gs_peak_LTavg',
#  'hurs_historical_IPSL-CM6A-LR_gs_peak_LTavg',
#  'pr_historical_IPSL-CM6A-LR_gs_peak_LTavg',
#  'rsds_historical_IPSL-CM6A-LR_gs_peak_LTavg',
#  'tas_historical_KIOST-ESM_gs_peak_LTavg',
#  'hurs_historical_KIOST-ESM_gs_peak_LTavg',
#  'pr_historical_KIOST-ESM_gs_peak_LTavg',
#  'rsds_historical_KIOST-ESM_gs_peak_LTavg',
#  'tas_historical_MIROC6_gs_peak_LTavg',
#  'hurs_historical_MIROC6_gs_peak_LTavg',
#  'pr_historical_MIROC6_gs_peak_LTavg',
#  'rsds_historical_MIROC6_gs_peak_LTavg',
#  'tas_historical_MPI-ESM1-2-LR_gs_peak_LTavg',
#  'hurs_historical_MPI-ESM1-2-LR_gs_peak_LTavg',
#  'pr_historical_MPI-ESM1-2-LR_gs_peak_LTavg',
#  'rsds_historical_MPI-ESM1-2-LR_gs_peak_LTavg',
#  'tas_historical_MRI-ESM2-0_gs_peak_LTavg',
#  'hurs_historical_MRI-ESM2-0_gs_peak_LTavg',
#  'pr_historical_MRI-ESM2-0_gs_peak_LTavg',
#  'rsds_historical_MRI-ESM2-0_gs_peak_LTavg',
#  'tas_historical_NorESM2-MM_gs_peak_LTavg',
#  'hurs_historical_NorESM2-MM_gs_peak_LTavg',
#  'pr_historical_NorESM2-MM_gs_peak_LTavg',
#  'rsds_historical_NorESM2-MM_gs_peak_LTavg',
#  'tas_historical_UKESM1-0-LL_gs_peak_LTavg',
#  'hurs_historical_UKESM1-0-LL_gs_peak_LTavg',
#  'pr_historical_UKESM1-0-LL_gs_peak_LTavg',
#  'rsds_historical_UKESM1-0-LL_gs_peak_LTavg',
#  'vpd_historical_ACCESS-CM2_gs_LTavg',
#  'par_historical_ACCESS-CM2_gs_LTavg',
#  'vpd_historical_CanESM5_gs_LTavg',
#  'par_historical_CanESM5_gs_LTavg',
#  'vpd_historical_CESM2_gs_LTavg',
#  'par_historical_CESM2_gs_LTavg',
#  'vpd_historical_CNRM-CM6-1_gs_LTavg',
#  'par_historical_CNRM-CM6-1_gs_LTavg',
#  'vpd_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'par_historical_EC-Earth3-Veg-LR_gs_LTavg',
#  'vpd_historical_FGOALS-g3_gs_LTavg',
#  'par_historical_FGOALS-g3_gs_LTavg',
#  'vpd_historical_GFDL-CM4_gs_LTavg',
#  'par_historical_GFDL-CM4_gs_LTavg',
#  'vpd_historical_GISS-E2-1-G_gs_LTavg',
#  'par_historical_GISS-E2-1-G_gs_LTavg',
#  'vpd_historical_IITM-ESM_gs_LTavg',
#  'par_historical_IITM-ESM_gs_LTavg',
#  'vpd_historical_INM-CM5-0_gs_LTavg',
#  'par_historical_INM-CM5-0_gs_LTavg',
#  'vpd_historical_IPSL-CM6A-LR_gs_LTavg',
#  'par_historical_IPSL-CM6A-LR_gs_LTavg',
#  'vpd_historical_KIOST-ESM_gs_LTavg',
#  'par_historical_KIOST-ESM_gs_LTavg',
#  'vpd_historical_MIROC6_gs_LTavg',
#  'par_historical_MIROC6_gs_LTavg',
#  'vpd_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'par_historical_MPI-ESM1-2-LR_gs_LTavg',
#  'vpd_historical_MRI-ESM2-0_gs_LTavg',
#  'par_historical_MRI-ESM2-0_gs_LTavg',
#  'vpd_historical_NorESM2-MM_gs_LTavg',
#  'par_historical_NorESM2-MM_gs_LTavg',
#  'vpd_historical_UKESM1-0-LL_gs_LTavg',
#  'par_historical_UKESM1-0-LL_gs_LTavg',
#  'year',
#  'tas_ssp245_ACCESS-CM2',
#  'hurs_ssp245_ACCESS-CM2',
#  'pr_ssp245_ACCESS-CM2',
#  'rsds_ssp245_ACCESS-CM2',
#  'tas_ssp585_ACCESS-CM2',
#  'hurs_ssp585_ACCESS-CM2',
#  'pr_ssp585_ACCESS-CM2',
#  'rsds_ssp585_ACCESS-CM2',
#  'tas_ssp245_CanESM5',
#  'hurs_ssp245_CanESM5',
#  'pr_ssp245_CanESM5',
#  'rsds_ssp245_CanESM5',
#  'tas_ssp585_CanESM5',
#  'hurs_ssp585_CanESM5',
#  'pr_ssp585_CanESM5',
#  'rsds_ssp585_CanESM5',
#  'tas_ssp245_CESM2',
#  'hurs_ssp245_CESM2',
#  'pr_ssp245_CESM2',
#  'rsds_ssp245_CESM2',
#  'tas_ssp585_CESM2',
#  'hurs_ssp585_CESM2',
#  'pr_ssp585_CESM2',
#  'rsds_ssp585_CESM2',
#  'tas_ssp245_CNRM-CM6-1',
#  'hurs_ssp245_CNRM-CM6-1',
#  'pr_ssp245_CNRM-CM6-1',
#  'rsds_ssp245_CNRM-CM6-1',
#  'tas_ssp585_CNRM-CM6-1',
#  'hurs_ssp585_CNRM-CM6-1',
#  'pr_ssp585_CNRM-CM6-1',
#  'rsds_ssp585_CNRM-CM6-1',
#  'tas_ssp245_EC-Earth3-Veg-LR',
#  'hurs_ssp245_EC-Earth3-Veg-LR',
#  'pr_ssp245_EC-Earth3-Veg-LR',
#  'rsds_ssp245_EC-Earth3-Veg-LR',
#  'tas_ssp585_EC-Earth3-Veg-LR',
#  'hurs_ssp585_EC-Earth3-Veg-LR',
#  'pr_ssp585_EC-Earth3-Veg-LR',
#  'rsds_ssp585_EC-Earth3-Veg-LR',
#  'tas_ssp245_FGOALS-g3',
#  'hurs_ssp245_FGOALS-g3',
#  'pr_ssp245_FGOALS-g3',
#  'rsds_ssp245_FGOALS-g3',
#  'tas_ssp585_FGOALS-g3',
#  'hurs_ssp585_FGOALS-g3',
#  'pr_ssp585_FGOALS-g3',
#  'rsds_ssp585_FGOALS-g3',
#  'tas_ssp245_GFDL-CM4',
#  'hurs_ssp245_GFDL-CM4',
#  'pr_ssp245_GFDL-CM4',
#  'rsds_ssp245_GFDL-CM4',
#  'tas_ssp585_GFDL-CM4',
#  'hurs_ssp585_GFDL-CM4',
#  'pr_ssp585_GFDL-CM4',
#  'rsds_ssp585_GFDL-CM4',
#  'tas_ssp245_GISS-E2-1-G',
#  'hurs_ssp245_GISS-E2-1-G',
#  'pr_ssp245_GISS-E2-1-G',
#  'rsds_ssp245_GISS-E2-1-G',
#  'tas_ssp585_GISS-E2-1-G',
#  'hurs_ssp585_GISS-E2-1-G',
#  'pr_ssp585_GISS-E2-1-G',
#  'rsds_ssp585_GISS-E2-1-G',
#  'tas_ssp245_IITM-ESM',
#  'hurs_ssp245_IITM-ESM',
#  'pr_ssp245_IITM-ESM',
#  'rsds_ssp245_IITM-ESM',
#  'tas_ssp585_IITM-ESM',
#  'hurs_ssp585_IITM-ESM',
#  'pr_ssp585_IITM-ESM',
#  'rsds_ssp585_IITM-ESM',
#  'tas_ssp245_INM-CM5-0',
#  'hurs_ssp245_INM-CM5-0',
#  'pr_ssp245_INM-CM5-0',
#  'rsds_ssp245_INM-CM5-0',
#  'tas_ssp585_INM-CM5-0',
#  'hurs_ssp585_INM-CM5-0',
#  'pr_ssp585_INM-CM5-0',
#  'rsds_ssp585_INM-CM5-0',
#  'tas_ssp245_IPSL-CM6A-LR',
#  'hurs_ssp245_IPSL-CM6A-LR',
#  'pr_ssp245_IPSL-CM6A-LR',
#  'rsds_ssp245_IPSL-CM6A-LR',
#  'tas_ssp585_IPSL-CM6A-LR',
#  'hurs_ssp585_IPSL-CM6A-LR',
#  'pr_ssp585_IPSL-CM6A-LR',
#  'rsds_ssp585_IPSL-CM6A-LR',
#  'tas_ssp245_KIOST-ESM',
#  'hurs_ssp245_KIOST-ESM',
#  'pr_ssp245_KIOST-ESM',
#  'rsds_ssp245_KIOST-ESM',
#  'tas_ssp585_KIOST-ESM',
#  'hurs_ssp585_KIOST-ESM',
#  'pr_ssp585_KIOST-ESM',
#  'rsds_ssp585_KIOST-ESM',
#  'tas_ssp245_MIROC6',
#  'hurs_ssp245_MIROC6',
#  'pr_ssp245_MIROC6',
#  'rsds_ssp245_MIROC6',
#  'tas_ssp585_MIROC6',
#  'hurs_ssp585_MIROC6',
#  'pr_ssp585_MIROC6',
#  'rsds_ssp585_MIROC6',
#  'tas_ssp245_MPI-ESM1-2-LR',
#  'hurs_ssp245_MPI-ESM1-2-LR',
#  'pr_ssp245_MPI-ESM1-2-LR',
#  'rsds_ssp245_MPI-ESM1-2-LR',
#  'tas_ssp585_MPI-ESM1-2-LR',
#  'hurs_ssp585_MPI-ESM1-2-LR',
#  'pr_ssp585_MPI-ESM1-2-LR',
#  'rsds_ssp585_MPI-ESM1-2-LR',
#  'tas_ssp245_MRI-ESM2-0',
#  'hurs_ssp245_MRI-ESM2-0',
#  'pr_ssp245_MRI-ESM2-0',
#  'rsds_ssp245_MRI-ESM2-0',
#  'tas_ssp585_MRI-ESM2-0',
#  'hurs_ssp585_MRI-ESM2-0',
#  'pr_ssp585_MRI-ESM2-0',
#  'rsds_ssp585_MRI-ESM2-0',
#  'tas_ssp245_NorESM2-MM',
#  'hurs_ssp245_NorESM2-MM',
#  'pr_ssp245_NorESM2-MM',
#  'rsds_ssp245_NorESM2-MM',
#  'tas_ssp585_NorESM2-MM',
#  'hurs_ssp585_NorESM2-MM',
#  'pr_ssp585_NorESM2-MM',
#  'rsds_ssp585_NorESM2-MM',
#  'tas_ssp245_UKESM1-0-LL',
#  'hurs_ssp245_UKESM1-0-LL',
#  'pr_ssp245_UKESM1-0-LL',
#  'rsds_ssp245_UKESM1-0-LL',
#  'tas_ssp585_UKESM1-0-LL',
#  'hurs_ssp585_UKESM1-0-LL',
#  'pr_ssp585_UKESM1-0-LL',
#  'rsds_ssp585_UKESM1-0-LL',
#  'tas_ssp245_ACCESS-CM2_gs',
#  'hurs_ssp245_ACCESS-CM2_gs',
#  'pr_ssp245_ACCESS-CM2_gs',
#  'rsds_ssp245_ACCESS-CM2_gs',
#  'tas_ssp585_ACCESS-CM2_gs',
#  'hurs_ssp585_ACCESS-CM2_gs',
#  'pr_ssp585_ACCESS-CM2_gs',
#  'rsds_ssp585_ACCESS-CM2_gs',
#  'tas_ssp245_CanESM5_gs',
#  'hurs_ssp245_CanESM5_gs',
#  'pr_ssp245_CanESM5_gs',
#  'rsds_ssp245_CanESM5_gs',
#  'tas_ssp585_CanESM5_gs',
#  'hurs_ssp585_CanESM5_gs',
#  'pr_ssp585_CanESM5_gs',
#  'rsds_ssp585_CanESM5_gs',
#  'tas_ssp245_CESM2_gs',
#  'hurs_ssp245_CESM2_gs',
#  'pr_ssp245_CESM2_gs',
#  'rsds_ssp245_CESM2_gs',
#  'tas_ssp585_CESM2_gs',
#  'hurs_ssp585_CESM2_gs',
#  'pr_ssp585_CESM2_gs',
#  'rsds_ssp585_CESM2_gs',
#  'tas_ssp245_CNRM-CM6-1_gs',
#  'hurs_ssp245_CNRM-CM6-1_gs',
#  'pr_ssp245_CNRM-CM6-1_gs',
#  'rsds_ssp245_CNRM-CM6-1_gs',
#  'tas_ssp585_CNRM-CM6-1_gs',
#  'hurs_ssp585_CNRM-CM6-1_gs',
#  'pr_ssp585_CNRM-CM6-1_gs',
#  'rsds_ssp585_CNRM-CM6-1_gs',
#  'tas_ssp245_EC-Earth3-Veg-LR_gs',
#  'hurs_ssp245_EC-Earth3-Veg-LR_gs',
#  'pr_ssp245_EC-Earth3-Veg-LR_gs',
#  'rsds_ssp245_EC-Earth3-Veg-LR_gs',
#  'tas_ssp585_EC-Earth3-Veg-LR_gs',
#  'hurs_ssp585_EC-Earth3-Veg-LR_gs',
#  'pr_ssp585_EC-Earth3-Veg-LR_gs',
#  'rsds_ssp585_EC-Earth3-Veg-LR_gs',
#  'tas_ssp245_FGOALS-g3_gs',
#  'hurs_ssp245_FGOALS-g3_gs',
#  'pr_ssp245_FGOALS-g3_gs',
#  'rsds_ssp245_FGOALS-g3_gs',
#  'tas_ssp585_FGOALS-g3_gs',
#  'hurs_ssp585_FGOALS-g3_gs',
#  'pr_ssp585_FGOALS-g3_gs',
#  'rsds_ssp585_FGOALS-g3_gs',
#  'tas_ssp245_GFDL-CM4_gs',
#  'hurs_ssp245_GFDL-CM4_gs',
#  'pr_ssp245_GFDL-CM4_gs',
#  'rsds_ssp245_GFDL-CM4_gs',
#  'tas_ssp585_GFDL-CM4_gs',
#  'hurs_ssp585_GFDL-CM4_gs',
#  'pr_ssp585_GFDL-CM4_gs',
#  'rsds_ssp585_GFDL-CM4_gs',
#  'tas_ssp245_GISS-E2-1-G_gs',
#  'hurs_ssp245_GISS-E2-1-G_gs',
#  'pr_ssp245_GISS-E2-1-G_gs',
#  'rsds_ssp245_GISS-E2-1-G_gs',
#  'tas_ssp585_GISS-E2-1-G_gs',
#  'hurs_ssp585_GISS-E2-1-G_gs',
#  'pr_ssp585_GISS-E2-1-G_gs',
#  'rsds_ssp585_GISS-E2-1-G_gs',
#  'tas_ssp245_IITM-ESM_gs',
#  'hurs_ssp245_IITM-ESM_gs',
#  'pr_ssp245_IITM-ESM_gs',
#  'rsds_ssp245_IITM-ESM_gs',
#  'tas_ssp585_IITM-ESM_gs',
#  'hurs_ssp585_IITM-ESM_gs',
#  'pr_ssp585_IITM-ESM_gs',
#  'rsds_ssp585_IITM-ESM_gs',
#  'tas_ssp245_INM-CM5-0_gs',
#  'hurs_ssp245_INM-CM5-0_gs',
#  'pr_ssp245_INM-CM5-0_gs',
#  'rsds_ssp245_INM-CM5-0_gs',
#  'tas_ssp585_INM-CM5-0_gs',
#  'hurs_ssp585_INM-CM5-0_gs',
#  'pr_ssp585_INM-CM5-0_gs',
#  'rsds_ssp585_INM-CM5-0_gs',
#  'tas_ssp245_IPSL-CM6A-LR_gs',
#  'hurs_ssp245_IPSL-CM6A-LR_gs',
#  'pr_ssp245_IPSL-CM6A-LR_gs',
#  'rsds_ssp245_IPSL-CM6A-LR_gs',
#  'tas_ssp585_IPSL-CM6A-LR_gs',
#  'hurs_ssp585_IPSL-CM6A-LR_gs',
#  'pr_ssp585_IPSL-CM6A-LR_gs',
#  'rsds_ssp585_IPSL-CM6A-LR_gs',
#  'tas_ssp245_KIOST-ESM_gs',
#  'hurs_ssp245_KIOST-ESM_gs',
#  'pr_ssp245_KIOST-ESM_gs',
#  'rsds_ssp245_KIOST-ESM_gs',
#  'tas_ssp585_KIOST-ESM_gs',
#  'hurs_ssp585_KIOST-ESM_gs',
#  'pr_ssp585_KIOST-ESM_gs',
#  'rsds_ssp585_KIOST-ESM_gs',
#  'tas_ssp245_MIROC6_gs',
#  'hurs_ssp245_MIROC6_gs',
#  'pr_ssp245_MIROC6_gs',
#  'rsds_ssp245_MIROC6_gs',
#  'tas_ssp585_MIROC6_gs',
#  'hurs_ssp585_MIROC6_gs',
#  'pr_ssp585_MIROC6_gs',
#  'rsds_ssp585_MIROC6_gs',
#  'tas_ssp245_MPI-ESM1-2-LR_gs',
#  'hurs_ssp245_MPI-ESM1-2-LR_gs',
#  'pr_ssp245_MPI-ESM1-2-LR_gs',
#  'rsds_ssp245_MPI-ESM1-2-LR_gs',
#  'tas_ssp585_MPI-ESM1-2-LR_gs',
#  'hurs_ssp585_MPI-ESM1-2-LR_gs',
#  'pr_ssp585_MPI-ESM1-2-LR_gs',
#  'rsds_ssp585_MPI-ESM1-2-LR_gs',
#  'tas_ssp245_MRI-ESM2-0_gs',
#  'hurs_ssp245_MRI-ESM2-0_gs',
#  'pr_ssp245_MRI-ESM2-0_gs',
#  'rsds_ssp245_MRI-ESM2-0_gs',
#  'tas_ssp585_MRI-ESM2-0_gs',
#  'hurs_ssp585_MRI-ESM2-0_gs',
#  'pr_ssp585_MRI-ESM2-0_gs',
#  'rsds_ssp585_MRI-ESM2-0_gs',
#  'tas_ssp245_NorESM2-MM_gs',
#  'hurs_ssp245_NorESM2-MM_gs',
#  'pr_ssp245_NorESM2-MM_gs',
#  'rsds_ssp245_NorESM2-MM_gs',
#  'tas_ssp585_NorESM2-MM_gs',
#  'hurs_ssp585_NorESM2-MM_gs',
#  'pr_ssp585_NorESM2-MM_gs',
#  'rsds_ssp585_NorESM2-MM_gs',
#  'tas_ssp245_UKESM1-0-LL_gs',
#  'hurs_ssp245_UKESM1-0-LL_gs',
#  'pr_ssp245_UKESM1-0-LL_gs',
#  'rsds_ssp245_UKESM1-0-LL_gs',
#  'tas_ssp585_UKESM1-0-LL_gs',
#  'hurs_ssp585_UKESM1-0-LL_gs',
#  'pr_ssp585_UKESM1-0-LL_gs',
#  'rsds_ssp585_UKESM1-0-LL_gs',
#  'tas_ssp245_ACCESS-CM2_gs_peak',
#  'hurs_ssp245_ACCESS-CM2_gs_peak',
#  'pr_ssp245_ACCESS-CM2_gs_peak',
#  'rsds_ssp245_ACCESS-CM2_gs_peak',
#  'tas_ssp585_ACCESS-CM2_gs_peak',
#  'hurs_ssp585_ACCESS-CM2_gs_peak',
#  'pr_ssp585_ACCESS-CM2_gs_peak',
#  'rsds_ssp585_ACCESS-CM2_gs_peak',
#  'tas_ssp245_CanESM5_gs_peak',
#  'hurs_ssp245_CanESM5_gs_peak',
#  'pr_ssp245_CanESM5_gs_peak',
#  'rsds_ssp245_CanESM5_gs_peak',
#  'tas_ssp585_CanESM5_gs_peak',
#  'hurs_ssp585_CanESM5_gs_peak',
#  'pr_ssp585_CanESM5_gs_peak',
#  'rsds_ssp585_CanESM5_gs_peak',
#  'tas_ssp245_CESM2_gs_peak',
#  'hurs_ssp245_CESM2_gs_peak',
#  'pr_ssp245_CESM2_gs_peak',
#  'rsds_ssp245_CESM2_gs_peak',
#  'tas_ssp585_CESM2_gs_peak',
#  'hurs_ssp585_CESM2_gs_peak',
#  'pr_ssp585_CESM2_gs_peak',
#  'rsds_ssp585_CESM2_gs_peak',
#  'tas_ssp245_CNRM-CM6-1_gs_peak',
#  'hurs_ssp245_CNRM-CM6-1_gs_peak',
#  'pr_ssp245_CNRM-CM6-1_gs_peak',
#  'rsds_ssp245_CNRM-CM6-1_gs_peak',
#  'tas_ssp585_CNRM-CM6-1_gs_peak',
#  'hurs_ssp585_CNRM-CM6-1_gs_peak',
#  'pr_ssp585_CNRM-CM6-1_gs_peak',
#  'rsds_ssp585_CNRM-CM6-1_gs_peak',
#  'tas_ssp245_EC-Earth3-Veg-LR_gs_peak',
#  'hurs_ssp245_EC-Earth3-Veg-LR_gs_peak',
#  'pr_ssp245_EC-Earth3-Veg-LR_gs_peak',
#  'rsds_ssp245_EC-Earth3-Veg-LR_gs_peak',
#  'tas_ssp585_EC-Earth3-Veg-LR_gs_peak',
#  'hurs_ssp585_EC-Earth3-Veg-LR_gs_peak',
#  'pr_ssp585_EC-Earth3-Veg-LR_gs_peak',
#  'rsds_ssp585_EC-Earth3-Veg-LR_gs_peak',
#  'tas_ssp245_FGOALS-g3_gs_peak',
#  'hurs_ssp245_FGOALS-g3_gs_peak',
#  'pr_ssp245_FGOALS-g3_gs_peak',
#  'rsds_ssp245_FGOALS-g3_gs_peak',
#  'tas_ssp585_FGOALS-g3_gs_peak',
#  'hurs_ssp585_FGOALS-g3_gs_peak',
#  'pr_ssp585_FGOALS-g3_gs_peak',
#  'rsds_ssp585_FGOALS-g3_gs_peak',
#  'tas_ssp245_GFDL-CM4_gs_peak',
#  'hurs_ssp245_GFDL-CM4_gs_peak',
#  'pr_ssp245_GFDL-CM4_gs_peak',
#  'rsds_ssp245_GFDL-CM4_gs_peak',
#  'tas_ssp585_GFDL-CM4_gs_peak',
#  'hurs_ssp585_GFDL-CM4_gs_peak',
#  'pr_ssp585_GFDL-CM4_gs_peak',
#  'rsds_ssp585_GFDL-CM4_gs_peak',
#  'tas_ssp245_GISS-E2-1-G_gs_peak',
#  'hurs_ssp245_GISS-E2-1-G_gs_peak',
#  'pr_ssp245_GISS-E2-1-G_gs_peak',
#  'rsds_ssp245_GISS-E2-1-G_gs_peak',
#  'tas_ssp585_GISS-E2-1-G_gs_peak',
#  'hurs_ssp585_GISS-E2-1-G_gs_peak',
#  'pr_ssp585_GISS-E2-1-G_gs_peak',
#  'rsds_ssp585_GISS-E2-1-G_gs_peak',
#  'tas_ssp245_IITM-ESM_gs_peak',
#  'hurs_ssp245_IITM-ESM_gs_peak',
#  'pr_ssp245_IITM-ESM_gs_peak',
#  'rsds_ssp245_IITM-ESM_gs_peak',
#  'tas_ssp585_IITM-ESM_gs_peak',
#  'hurs_ssp585_IITM-ESM_gs_peak',
#  'pr_ssp585_IITM-ESM_gs_peak',
#  'rsds_ssp585_IITM-ESM_gs_peak',
#  'tas_ssp245_INM-CM5-0_gs_peak',
#  'hurs_ssp245_INM-CM5-0_gs_peak',
#  'pr_ssp245_INM-CM5-0_gs_peak',
#  'rsds_ssp245_INM-CM5-0_gs_peak',
#  'tas_ssp585_INM-CM5-0_gs_peak',
#  'hurs_ssp585_INM-CM5-0_gs_peak',
#  'pr_ssp585_INM-CM5-0_gs_peak',
#  'rsds_ssp585_INM-CM5-0_gs_peak',
#  'tas_ssp245_IPSL-CM6A-LR_gs_peak',
#  'hurs_ssp245_IPSL-CM6A-LR_gs_peak',
#  'pr_ssp245_IPSL-CM6A-LR_gs_peak',
#  'rsds_ssp245_IPSL-CM6A-LR_gs_peak',
#  'tas_ssp585_IPSL-CM6A-LR_gs_peak',
#  'hurs_ssp585_IPSL-CM6A-LR_gs_peak',
#  'pr_ssp585_IPSL-CM6A-LR_gs_peak',
#  'rsds_ssp585_IPSL-CM6A-LR_gs_peak',
#  'tas_ssp245_KIOST-ESM_gs_peak',
#  'hurs_ssp245_KIOST-ESM_gs_peak',
#  'pr_ssp245_KIOST-ESM_gs_peak',
#  'rsds_ssp245_KIOST-ESM_gs_peak',
#  'tas_ssp585_KIOST-ESM_gs_peak',
#  'hurs_ssp585_KIOST-ESM_gs_peak',
#  'pr_ssp585_KIOST-ESM_gs_peak',
#  'rsds_ssp585_KIOST-ESM_gs_peak',
#  'tas_ssp245_MIROC6_gs_peak',
#  'hurs_ssp245_MIROC6_gs_peak',
#  'pr_ssp245_MIROC6_gs_peak',
#  'rsds_ssp245_MIROC6_gs_peak',
#  'tas_ssp585_MIROC6_gs_peak',
#  'hurs_ssp585_MIROC6_gs_peak',
#  'pr_ssp585_MIROC6_gs_peak',
#  'rsds_ssp585_MIROC6_gs_peak',
#  'tas_ssp245_MPI-ESM1-2-LR_gs_peak',
#  'hurs_ssp245_MPI-ESM1-2-LR_gs_peak',
#  'pr_ssp245_MPI-ESM1-2-LR_gs_peak',
#  'rsds_ssp245_MPI-ESM1-2-LR_gs_peak',
#  'tas_ssp585_MPI-ESM1-2-LR_gs_peak',
#  'hurs_ssp585_MPI-ESM1-2-LR_gs_peak',
#  'pr_ssp585_MPI-ESM1-2-LR_gs_peak',
#  'rsds_ssp585_MPI-ESM1-2-LR_gs_peak',
#  'tas_ssp245_MRI-ESM2-0_gs_peak',
#  'hurs_ssp245_MRI-ESM2-0_gs_peak',
#  'pr_ssp245_MRI-ESM2-0_gs_peak',
#  'rsds_ssp245_MRI-ESM2-0_gs_peak',
#  'tas_ssp585_MRI-ESM2-0_gs_peak',
#  'hurs_ssp585_MRI-ESM2-0_gs_peak',
#  'pr_ssp585_MRI-ESM2-0_gs_peak',
#  'rsds_ssp585_MRI-ESM2-0_gs_peak',
#  'tas_ssp245_NorESM2-MM_gs_peak',
#  'hurs_ssp245_NorESM2-MM_gs_peak',
#  'pr_ssp245_NorESM2-MM_gs_peak',
#  'rsds_ssp245_NorESM2-MM_gs_peak',
#  'tas_ssp585_NorESM2-MM_gs_peak',
#  'hurs_ssp585_NorESM2-MM_gs_peak',
#  'pr_ssp585_NorESM2-MM_gs_peak',
#  'rsds_ssp585_NorESM2-MM_gs_peak',
#  'tas_ssp245_UKESM1-0-LL_gs_peak',
#  'hurs_ssp245_UKESM1-0-LL_gs_peak',
#  'pr_ssp245_UKESM1-0-LL_gs_peak',
#  'rsds_ssp245_UKESM1-0-LL_gs_peak',
#  'tas_ssp585_UKESM1-0-LL_gs_peak',
#  'hurs_ssp585_UKESM1-0-LL_gs_peak',
#  'pr_ssp585_UKESM1-0-LL_gs_peak',
#  'rsds_ssp585_UKESM1-0-LL_gs_peak',
#  'CO2_ssp245',
#  'CO2_ssp585',
#  'par_ssp245_ACCESS-CM2_gs',
#  'vpd_ssp245_ACCESS-CM2_gs',
#  'rf_alpha_ssp245_ACCESS-CM2_gs',
#  'rf_lambda_ssp245_ACCESS-CM2_gs',
#  'pet_ssp245_ACCESS-CM2_gs',
#  'par_ssp585_ACCESS-CM2_gs',
#  'vpd_ssp585_ACCESS-CM2_gs',
#  'rf_alpha_ssp585_ACCESS-CM2_gs',
#  'rf_lambda_ssp585_ACCESS-CM2_gs',
#  'pet_ssp585_ACCESS-CM2_gs',
#  'par_ssp245_CanESM5_gs',
#  'vpd_ssp245_CanESM5_gs',
#  'rf_alpha_ssp245_CanESM5_gs',
#  'rf_lambda_ssp245_CanESM5_gs',
#  'pet_ssp245_CanESM5_gs',
#  'par_ssp585_CanESM5_gs',
#  'vpd_ssp585_CanESM5_gs',
#  'rf_alpha_ssp585_CanESM5_gs',
#  'rf_lambda_ssp585_CanESM5_gs',
#  'pet_ssp585_CanESM5_gs',
#  'par_ssp245_CESM2_gs',
#  'vpd_ssp245_CESM2_gs',
#  'rf_alpha_ssp245_CESM2_gs',
#  'rf_lambda_ssp245_CESM2_gs',
#  'pet_ssp245_CESM2_gs',
#  'par_ssp585_CESM2_gs',
#  'vpd_ssp585_CESM2_gs',
#  'rf_alpha_ssp585_CESM2_gs',
#  'rf_lambda_ssp585_CESM2_gs',
#  'pet_ssp585_CESM2_gs',
#  'par_ssp245_CNRM-CM6-1_gs',
#  'vpd_ssp245_CNRM-CM6-1_gs',
#  'rf_alpha_ssp245_CNRM-CM6-1_gs',
#  'rf_lambda_ssp245_CNRM-CM6-1_gs',
#  'pet_ssp245_CNRM-CM6-1_gs',
#  'par_ssp585_CNRM-CM6-1_gs',
#  'vpd_ssp585_CNRM-CM6-1_gs',
#  'rf_alpha_ssp585_CNRM-CM6-1_gs',
#  'rf_lambda_ssp585_CNRM-CM6-1_gs',
#  'pet_ssp585_CNRM-CM6-1_gs',
#  'par_ssp245_EC-Earth3-Veg-LR_gs',
#  'vpd_ssp245_EC-Earth3-Veg-LR_gs',
#  'rf_alpha_ssp245_EC-Earth3-Veg-LR_gs',
#  'rf_lambda_ssp245_EC-Earth3-Veg-LR_gs',
#  'pet_ssp245_EC-Earth3-Veg-LR_gs',
#  'par_ssp585_EC-Earth3-Veg-LR_gs',
#  'vpd_ssp585_EC-Earth3-Veg-LR_gs',
#  'rf_alpha_ssp585_EC-Earth3-Veg-LR_gs',
#  'rf_lambda_ssp585_EC-Earth3-Veg-LR_gs',
#  'pet_ssp585_EC-Earth3-Veg-LR_gs',
#  'par_ssp245_FGOALS-g3_gs',
#  'vpd_ssp245_FGOALS-g3_gs',
#  'rf_alpha_ssp245_FGOALS-g3_gs',
#  'rf_lambda_ssp245_FGOALS-g3_gs',
#  'pet_ssp245_FGOALS-g3_gs',
#  'par_ssp585_FGOALS-g3_gs',
#  'vpd_ssp585_FGOALS-g3_gs',
#  'rf_alpha_ssp585_FGOALS-g3_gs',
#  'rf_lambda_ssp585_FGOALS-g3_gs',
#  'pet_ssp585_FGOALS-g3_gs',
#  'par_ssp245_GFDL-CM4_gs',
#  'vpd_ssp245_GFDL-CM4_gs',
#  'rf_alpha_ssp245_GFDL-CM4_gs',
#  'rf_lambda_ssp245_GFDL-CM4_gs',
#  'pet_ssp245_GFDL-CM4_gs',
#  'par_ssp585_GFDL-CM4_gs',
#  'vpd_ssp585_GFDL-CM4_gs',
#  'rf_alpha_ssp585_GFDL-CM4_gs',
#  'rf_lambda_ssp585_GFDL-CM4_gs',
#  'pet_ssp585_GFDL-CM4_gs',
#  'par_ssp245_GISS-E2-1-G_gs',
#  'vpd_ssp245_GISS-E2-1-G_gs',
#  'rf_alpha_ssp245_GISS-E2-1-G_gs',
#  'rf_lambda_ssp245_GISS-E2-1-G_gs',
#  'pet_ssp245_GISS-E2-1-G_gs',
#  'par_ssp585_GISS-E2-1-G_gs',
#  'vpd_ssp585_GISS-E2-1-G_gs',
#  'rf_alpha_ssp585_GISS-E2-1-G_gs',
#  'rf_lambda_ssp585_GISS-E2-1-G_gs',
#  'pet_ssp585_GISS-E2-1-G_gs',
#  'par_ssp245_IITM-ESM_gs',
#  'vpd_ssp245_IITM-ESM_gs',
#  'rf_alpha_ssp245_IITM-ESM_gs',
#  'rf_lambda_ssp245_IITM-ESM_gs',
#  'pet_ssp245_IITM-ESM_gs',
#  'par_ssp585_IITM-ESM_gs',
#  'vpd_ssp585_IITM-ESM_gs',
#  'rf_alpha_ssp585_IITM-ESM_gs',
#  'rf_lambda_ssp585_IITM-ESM_gs',
#  'pet_ssp585_IITM-ESM_gs',
#  'par_ssp245_INM-CM5-0_gs',
#  'vpd_ssp245_INM-CM5-0_gs',
#  'rf_alpha_ssp245_INM-CM5-0_gs',
#  'rf_lambda_ssp245_INM-CM5-0_gs',
#  'pet_ssp245_INM-CM5-0_gs',
#  'par_ssp585_INM-CM5-0_gs',
#  'vpd_ssp585_INM-CM5-0_gs',
#  'rf_alpha_ssp585_INM-CM5-0_gs',
#  'rf_lambda_ssp585_INM-CM5-0_gs',
#  'pet_ssp585_INM-CM5-0_gs',
#  'par_ssp245_IPSL-CM6A-LR_gs',
#  'vpd_ssp245_IPSL-CM6A-LR_gs',
#  'rf_alpha_ssp245_IPSL-CM6A-LR_gs',
#  'rf_lambda_ssp245_IPSL-CM6A-LR_gs',
#  'pet_ssp245_IPSL-CM6A-LR_gs',
#  'par_ssp585_IPSL-CM6A-LR_gs',
#  'vpd_ssp585_IPSL-CM6A-LR_gs',
#  'rf_alpha_ssp585_IPSL-CM6A-LR_gs',
#  'rf_lambda_ssp585_IPSL-CM6A-LR_gs',
#  'pet_ssp585_IPSL-CM6A-LR_gs',
#  'par_ssp245_KIOST-ESM_gs',
#  'vpd_ssp245_KIOST-ESM_gs',
#  'rf_alpha_ssp245_KIOST-ESM_gs',
#  'rf_lambda_ssp245_KIOST-ESM_gs',
#  'pet_ssp245_KIOST-ESM_gs',
#  'par_ssp585_KIOST-ESM_gs',
#  'vpd_ssp585_KIOST-ESM_gs',
#  'rf_alpha_ssp585_KIOST-ESM_gs',
#  'rf_lambda_ssp585_KIOST-ESM_gs',
#  'pet_ssp585_KIOST-ESM_gs',
#  'par_ssp245_MIROC6_gs',
#  'vpd_ssp245_MIROC6_gs',
#  'rf_alpha_ssp245_MIROC6_gs',
#  'rf_lambda_ssp245_MIROC6_gs',
#  'pet_ssp245_MIROC6_gs',
#  'par_ssp585_MIROC6_gs',
#  'vpd_ssp585_MIROC6_gs',
#  'rf_alpha_ssp585_MIROC6_gs',
#  'rf_lambda_ssp585_MIROC6_gs',
#  'pet_ssp585_MIROC6_gs',
#  'par_ssp245_MPI-ESM1-2-LR_gs',
#  'vpd_ssp245_MPI-ESM1-2-LR_gs',
#  'rf_alpha_ssp245_MPI-ESM1-2-LR_gs',
#  'rf_lambda_ssp245_MPI-ESM1-2-LR_gs',
#  'pet_ssp245_MPI-ESM1-2-LR_gs',
#  'par_ssp585_MPI-ESM1-2-LR_gs',
#  'vpd_ssp585_MPI-ESM1-2-LR_gs',
#  'rf_alpha_ssp585_MPI-ESM1-2-LR_gs',
#  'rf_lambda_ssp585_MPI-ESM1-2-LR_gs',
#  'pet_ssp585_MPI-ESM1-2-LR_gs',
#  'par_ssp245_MRI-ESM2-0_gs',
#  'vpd_ssp245_MRI-ESM2-0_gs',
#  'rf_alpha_ssp245_MRI-ESM2-0_gs',
#  'rf_lambda_ssp245_MRI-ESM2-0_gs',
#  'pet_ssp245_MRI-ESM2-0_gs',
#  'par_ssp585_MRI-ESM2-0_gs',
#  'vpd_ssp585_MRI-ESM2-0_gs',
#  'rf_alpha_ssp585_MRI-ESM2-0_gs',
#  'rf_lambda_ssp585_MRI-ESM2-0_gs',
#  'pet_ssp585_MRI-ESM2-0_gs',
#  'par_ssp245_NorESM2-MM_gs',
#  'vpd_ssp245_NorESM2-MM_gs',
#  'rf_alpha_ssp245_NorESM2-MM_gs',
#  'rf_lambda_ssp245_NorESM2-MM_gs',
#  'pet_ssp245_NorESM2-MM_gs',
#  'par_ssp585_NorESM2-MM_gs',
#  'vpd_ssp585_NorESM2-MM_gs',
#  'rf_alpha_ssp585_NorESM2-MM_gs',
#  'rf_lambda_ssp585_NorESM2-MM_gs',
#  'pet_ssp585_NorESM2-MM_gs',
#  'par_ssp245_UKESM1-0-LL_gs',
#  'vpd_ssp245_UKESM1-0-LL_gs',
#  'rf_alpha_ssp245_UKESM1-0-LL_gs',
#  'rf_lambda_ssp245_UKESM1-0-LL_gs',
#  'pet_ssp245_UKESM1-0-LL_gs',
#  'par_ssp585_UKESM1-0-LL_gs',
#  'vpd_ssp585_UKESM1-0-LL_gs',
#  ...]
